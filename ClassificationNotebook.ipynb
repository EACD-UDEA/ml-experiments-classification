# %% [markdown]
# # Reto de clasificación

# %% [markdown]
# ## Análisis exploratorio de datos

# %%
# Importación de librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip --upgrade
import pandas_profiling # Library for automatic EDA
# !pip install autoviz
from autoviz.AutoViz_Class import AutoViz_Class

# %matplotlib inline
pandas_profiling.__version__
# Out:
# '3.0.0'

# %%
# !git clone https://github.com/EACD-UDEA/ml-experiments-classification
# Out:
# Cloning into 'ml-experiments-classification'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 20 (delta 2), reused 19 (delta 1), pack-reused 0
# Unpacking objects: 100% (20/20), done.

# %%
# !cp -R ml-experiments-classification/* .

# %%
# Lectura de datos
FILEPATH = "train_classification.csv"
data = pd.read_csv(FILEPATH)
data.head(10)
# Out:
#    age  sex  cp  trtbps  chol  fbs  ...  exng  oldpeak  slp  caa  thall  y
# 0   54    1   2     150   232    0  ...     0      1.6    2    0      3  1
# 1   58    0   2     120   340    0  ...     0      0.0    2    0      2  1
# 2   47    1   0     112   204    0  ...     0      0.1    2    0      2  1
# 3   58    1   0     114   318    0  ...     0      4.4    0    3      1  0
# 4   58    1   0     100   234    0  ...     0      0.1    2    1      3  0
# 5   45    0   1     130   234    0  ...     0      0.6    1    0      2  1
# 6   50    0   1     120   244    0  ...     0      1.1    2    0      2  1
# 7   62    0   0     124   209    0  ...     0      0.0    2    0      2  1
# 8   65    1   0     120   177    0  ...     0      0.4    2    0      3  1
# 9   43    1   0     120   177    0  ...     1      2.5    1    0      3  0
#
# [10 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       203 non-null    int64
#  1   sex       203 non-null    int64
#  2   cp        203 non-null    int64
#  3   trtbps    203 non-null    int64
#  4   chol      203 non-null    int64
#  5   fbs       203 non-null    int64
#  6   restecg   203 non-null    int64
#  7   thalachh  203 non-null    int64
#  8   exng      203 non-null    int64
#  9   oldpeak   203 non-null    float64
#  10  slp       203 non-null    int64
#  11  caa       203 non-null    int64
#  12  thall     203 non-null    int64
#  13  y         203 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 22.3 KB

# %%
data.describe()
# Out:
#               age         sex          cp  ...         caa       thall           y
# count  203.000000  203.000000  203.000000  ...  203.000000  203.000000  203.000000
# mean    54.650246    0.660099    1.009852  ...    0.635468    2.330049    0.527094
# std      9.019826    0.474846    1.043557  ...    0.920139    0.600687    0.500500
# min     34.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     48.000000    0.000000    0.000000  ...    0.000000    2.000000    0.000000
# 50%     56.000000    1.000000    1.000000  ...    0.000000    2.000000    1.000000
# 75%     61.000000    1.000000    2.000000  ...    1.000000    3.000000    1.000000
# max     77.000000    1.000000    3.000000  ...    3.000000    3.000000    1.000000
#
# [8 rows x 14 columns]

# %%
report = pandas_profiling.ProfileReport(data)
display(report)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-07-02 23:14:12.122327&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
data.corr()
# Out:
#                age       sex        cp  ...       caa     thall         y
# age       1.000000 -0.076439 -0.121124  ...  0.383608  0.060700 -0.195826
# sex      -0.076439  1.000000 -0.053150  ...  0.156894  0.221694 -0.304756
# cp       -0.121124 -0.053150  1.000000  ... -0.181843 -0.202648  0.454443
# trtbps    0.285929 -0.130026  0.035117  ...  0.060556  0.031641 -0.039381
# chol      0.222281 -0.228943 -0.073893  ...  0.079430  0.043440 -0.024446
# fbs       0.119751  0.026061  0.208782  ...  0.055854 -0.063502  0.038252
# restecg  -0.171677 -0.071504 -0.036333  ... -0.101589  0.041799  0.067287
# thalachh -0.368137 -0.048187  0.319437  ... -0.286306 -0.094108  0.393463
# exng      0.135564  0.149802 -0.409183  ...  0.130382  0.225299 -0.447252
# oldpeak   0.178287  0.187119 -0.172920  ...  0.272655  0.252712 -0.423966
# slp      -0.120390 -0.086662  0.132203  ... -0.070714 -0.107729  0.333145
# caa       0.383608  0.156894 -0.181843  ...  1.000000  0.093361 -0.472928
# ...

# %% [markdown]
# A partir de la matriz de correlación, se observa que las variables más correlacionadas con `y` son `caa` y `exng`, cuyos valores son `-0.47` y `-0.45`, respectivamente. La variable `exng` es binaria e indica si el paciente presenta angina inducida por el ejercicio; y la variable `caa` es un número entero entre 0 y 3 que indica el número de vasos mayores.

# %% [markdown]
# ## Preprocesamiento

# %% [markdown]
# El conjunto de datos no contiene valores nulos ni valores atípicos, por lo que el preprocesamiento consiste en codificar las variables categóricas y estandarizar las variables numéricas.

# %% [markdown]
# ### Funciones para el preprocesamiento de datos

# %%
import typing as t
import typing_extensions as te

from sklearn.model_selection import train_test_split

class DatasetReader(te.Protocol):
    def __call__(self) -> pd.DataFrame:
        ...


SplitName = te.Literal["train", "test"]


def get_dataset(reader: DatasetReader, splits: t.Iterable[SplitName]):
    df = reader()
    df = clean_dataset(df)

    y = df["y"]
    X = df.drop(columns=["y"])
    X = X.astype({k: str for k in get_categorical_variables_values_mapping().keys()})
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=1
    )
    split_mapping = {"train": (X_train, y_train), "test": (X_test, y_test)}
    return {k: split_mapping[k] for k in splits}


def get_test_dataset(reader: DatasetReader, splits: t.Iterable[SplitName]):
    df = reader()
    df = clean_dataset(df)

    X = df
    X = X.astype({k: str for k in get_categorical_variables_values_mapping().keys()})

    split_mapping = {"test": X}
    return {k: split_mapping[k] for k in splits}


def clean_dataset(df: pd.DataFrame) -> pd.DataFrame:
    cleaning_fn = _chain(
        [

        ]
    )
    df = cleaning_fn(df)
    return df


def _chain(functions: t.List[t.Callable[[pd.DataFrame], pd.DataFrame]]):
    def helper(df):
        for fn in functions:
            df = fn(df)
        return df

    return helper


def get_categorical_column_names() -> t.List[str]:
    return "sex".split(",")


def get_binary_column_names() -> t.List[str]:
    return (
        "fbs,exng"
    ).split(",")


def get_numeric_column_names() -> t.List[str]:
    return (
        "age,cp,trtbps,chol,restecg,thalachh,oldpeak,slp,caa,thall"
    ).split(",")


def get_column_names() -> t.List[str]:
    return (
        "age,sex,cp,trtbps,chol,fbs,restecg,thalachh,exng,oldpeak,slp,caa,thall"
    ).split(",")


def get_categorical_variables_values_mapping() -> t.Dict[str, t.Sequence[str]]:
    return {
        "sex": ("0", "1")
    }

# %% [markdown]
# ## Modelado

# %% [markdown]
# ### Funciones para evaluar el desempeño del modelo

# %%
from sklearn.metrics import make_scorer, accuracy_score, f1_score, precision_score, recall_score

def get_metric_name_mapping():
    return {_accuracy(): accuracy_score, _f1(): f1_score, _precision(): precision_score, _recall(): recall_score}


def get_metric_function(name: str, **params):
    mapping = get_metric_name_mapping()

    def fn(y, y_pred):
        return mapping[name](y, y_pred, **params)

    return fn


def get_scoring_function(name: str, **params):
    mapping = {
        _accuracy(): make_scorer(accuracy_score, greater_is_better=True, **params),
        _f1(): make_scorer(f1_score, greater_is_better=True, **params),
        _precision(): make_scorer(precision_score, greater_is_better=True, **params),
        _recall(): make_scorer(recall_score, greater_is_better=True, **params),
    }
    return mapping[name]


def _accuracy():
    return "accuracy score"


def _f1():
    return "f1 score"


def _precision():
    return "precision score"


def _recall():
    return "recall score"

# %%
# !pip install -r ./requirements.txt

# %% [markdown]
# ## Hipótesis (iteración) 0. Modelo base y resultados

# %% [markdown]
# La hipótesis inicial propuesta afirma que la variable `exng` se puede usar como único predictor para determinar la probabilidad de tener un paro cardiaco. El modelo base planteado consiste en predecir la probabilidad de infarto agudo de miocardio con base en la variable `exng`, para lo cual se propone asignar la moda de `y` que tiene cada grupo de valores de `exng`; esto es, si `exng = 0`, se asigna el valor más frecuente de `y` cuando `exng = 0`, y lo mismo para el caso en el que `exng = 1`. Así pues, al implementar este modelo se obtiene una exactitud de 0.6557, una precisión de 0.7068 y una exhaustividad de 0.6797.

# %%
# Modificación del archivo YAML
import yaml

with open('config.yml', 'r') as file:
  config1 = yaml.load(file)

config1['estimator'].pop(0)
config1['estimator'].append({'name': 'exng-classifier','params': {}})
config1['datatest'] = {'filepath': './test_classification_students_fix.csv'}

config1

with open('config.yml', 'w') as file:
  yaml.dump(config1, file)

# %%
# Entrenamiento del modelo
import os
os.chdir("ml-experiments-classification")
# !python ./app.py train ./config.yml
# Out:
# ./app.py:180: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   content = yaml.load(f)

# %%
import os
folders = os.listdir('./models')
nombre = sorted(folders)[0]
print("Iteración 0: ", nombre)
# Out:
# Iteración 0:  2021-07-02 23-21

# %%
# Evaluación del modelo
# !python ./app.py eval ./config.yml "{nombre}"
# Out:
# ./app.py:180: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   content = yaml.load(f)

# %%
# !cat "./reports/{nombre}.yml"
# Out:
# accuracy score:
# - split: test
#   value: 0.6557377049180327
# f1 score:
# - split: test
#   value: 0.6557377049180327
# precision score:
# - split: test
#   value: 0.706766917293233
# recall score:
# - split: test
#   value: 0.6797385620915033

# %% [markdown]
# ## Hipótesis (iteración) 1. Modelo y resultados

# %% [markdown]
# Se propone otra hipótesis que afirma que la variable `caa` en conjunto con `exng` pueden dar mejores predicciones. Luego, con base en los resultados anteriores, se plantea mejorar el modelo añadiendo la variable `caa` como predictor. Similarmente, para cada combinación de valores de `exng` y `caa`, se propone asignar la moda de la variable objetivo `y` como resultado; por ejemplo, si `exng = 0` y `caa = 3`, se asigna el valor más frecuente de `y` cuando `exng = 0` y `caa = 3`. En este caso las métricas de desempeño del modelo mejoran, se obtiene una exactitud de 0.7049, una precisión de 0.7275 y una exhaustividad de 0.7200.

# %%
# Modificación del archivo YAML
import yaml

with open('config.yml', 'r') as file:
  config1 = yaml.load(file)

config1['estimator'].pop(0)
config1['estimator'].append({'name': 'twovar-classifier','params': {}})

config1

with open('config.yml', 'w') as file:
  yaml.dump(config1, file)

# %%
# Entrenamiento del modelo
# !python ./app.py train ./config.yml
# Out:
# ./app.py:180: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   content = yaml.load(f)

# %%
import os
folders = os.listdir('./models')
nombre = sorted(folders)[1]
print("Iteración 1: ", nombre)
# Out:
# Iteración 1:  2021-07-02 23-24

# %%
# Evaluación del modelo
# !python ./app.py eval ./config.yml "{nombre}"
# Out:
# ./app.py:180: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   content = yaml.load(f)

# %%
# !cat "./reports/{nombre}.yml"
# Out:
# accuracy score:
# - split: test
#   value: 0.7049180327868853
# f1 score:
# - split: test
#   value: 0.7049180327868853
# precision score:
# - split: test
#   value: 0.7274774774774775
# recall score:
# - split: test
#   value: 0.7200435729847494

# %% [markdown]
# ## Hipótesis (iteración) 2. Modelo y resultados

# %% [markdown]
# Una segunda iteración consiste en usar un modelo de árboles aleatorios, con el cual mejoró el desempeño. Se obtuvo una exactitud de 0.7541, una precisión de 0.7642 y una exhaustividad de 0.7642.

# %%
# Modificación del archivo YAML
import yaml

with open('config.yml', 'r') as file:
  config1 = yaml.load(file)

config1['estimator'].pop(0)
config1['estimator'].append({'name': 'random-forest-classifier','params': {}})

config1

with open('config.yml', 'w') as file:
  yaml.dump(config1, file)

# %%
# Entrenamiento del modelo
# !python ./app.py train ./config.yml
# Out:
# ./app.py:180: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   content = yaml.load(f)

# %%
import os
folders = os.listdir('./models')
nombre = sorted(folders)[2]
print("Iteración 2: ", nombre)
# Out:
# Iteración 2:  2021-07-02 23-25

# %%
# Evaluación del modelo
# !python ./app.py eval ./config.yml "{nombre}"
# Out:
# ./app.py:180: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   content = yaml.load(f)

# %%
# !cat "./reports/{nombre}.yml"
# Out:
# accuracy score:
# - split: test
#   value: 0.7704918032786885
# f1 score:
# - split: test
#   value: 0.7704918032786885
# precision score:
# - split: test
#   value: 0.7851648351648352
# recall score:
# - split: test
#   value: 0.7826797385620915

# %% [markdown]
# ## Hipótesis (iteración) 3. Modelo y resultados

# %% [markdown]
# Una tercera iteración consiste en usar un modelo lineal, específicamente clasificación por regresión de Ridge. Este modelo tuvo mejor desempeño que los de las iteraciones anteriores: una exactitud de 0.8033, una precisión de 0.8305 y una exhaustividad de 0.8197.

# %%
# Modificación del archivo YAML
import yaml

with open('config.yml', 'r') as file:
  config1 = yaml.load(file)

config1['estimator'].pop(0)
config1['estimator'].append({'name': 'ridge-classifier','params': {}})

config1

with open('config.yml', 'w') as file:
  yaml.dump(config1, file)

# %%
# Entrenamiento del modelo
# !python ./app.py train ./config.yml
# Out:
# ./app.py:180: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   content = yaml.load(f)

# %%
import os
folders = os.listdir('./models')
nombre = sorted(folders)[3]
print("Iteración 3: ", nombre)
# Out:
# Iteración 3:  2021-07-02 23-26

# %%
# Evaluación del modelo
# !python ./app.py eval ./config.yml "{nombre}"
# Out:
# ./app.py:180: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   content = yaml.load(f)

# %%
# !cat "./reports/{nombre}.yml"
# Out:
# accuracy score:
# - split: test
#   value: 0.8032786885245902
# f1 score:
# - split: test
#   value: 0.8032786885245902
# precision score:
# - split: test
#   value: 0.8305180180180181
# recall score:
# - split: test
#   value: 0.8197167755991286

# %% [markdown]
# ## Envío de resultados

# %%
#@app.command()
def predict(
    config_file: str,
    model_version: str,
    splits: t.List[str] = ["test"],
):
    output_dir = _load_config(config_file, "export")["output_dir"]
    saved_model = os.path.join(output_dir, model_version, "model.joblib")
    estimator = joblib.load(saved_model)
    dataset = _get_test_dataset(_load_config(config_file, "datatest"), splits=splits)
    predictions = list()
    for name, X in dataset.items():
        y_pred = estimator.predict(X)
        predictions.append(y_pred)
    
    predictions = [x.tolist() for x in predictions]
    predictions = predictions[0]
    
    # predictions = predictions[0].values
    # predictions = [x.tolist() for x in predictions]
    # predictions = predictions[0]
    
    URL = "https://qzbbjszmjk.execute-api.us-east-1.amazonaws.com/dev"

    results = {"id": "SebasMonsalve","email": "sebastian.monsalves@udea.edu.co", "task_type": "Classification" ,"predictions": predictions}
    headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}

    r = requests.post(url= URL+"/benchmarkin/", data = json.dumps(results) , headers=headers)
    print(r.text)
    
    return predictions

# %%
# Predicciones con el modelo
# !python ./app.py predict ./config.yml "{nombre}"
# Out:
# ./app.py:180: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   content = yaml.load(f)
# {"F1":0.8186986734049274}
